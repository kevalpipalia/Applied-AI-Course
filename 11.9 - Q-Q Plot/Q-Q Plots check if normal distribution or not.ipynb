# %%
import numpy as np
import pylab
import scipy.stats as stats

# %%
std_normal = np.random.normal(loc = 0, scale = 1, size = 1000)

for i in range(0,101):
    print(i,np.percentile(std_normal,i))
# Out:
# 0 -2.824891402095311
# 1 -2.402750906525301
# 2 -2.109794287870309
# 3 -1.973937369911778
# 4 -1.8006846959195444
# 5 -1.668434889188532
# 6 -1.5726528003103182
# 7 -1.4769110892863753
# 8 -1.4155971687782565
# 9 -1.3569679039810731
# 10 -1.2940060120046657
# 11 -1.2355743043239793
# 12 -1.181833475041506
# 13 -1.1361423538531208
# 14 -1.0941105252941588
# 15 -1.0466205948094756
# 16 -1.0090239926177191
# 17 -0.9596998915301947
# 18 -0.9166463107672429
# 19 -0.8805843391532296
# 20 -0.8302784020221308
# 21 -0.8080948380357316
# 22 -0.7754965450658675
# 23 -0.7320366727118816
# 24 -0.6994383099239889
# 25 -0.6754748454427131
# 26 -0.6497015474057748
# 27 -0.618685759639686
# 28 -0.5976593154372147
# 29 -0.5698239511177097
# 30 -0.5484778244158535
# 31 -0.5212149946424215
# 32 -0.49141821460190205
# 33 -0.45880074769675516
# 34 -0.43250007776312827
# 35 -0.3998028550202112
# 36 -0.3655272381054243
# 37 -0.3437792537756118
# 38 -0.3134464744338683
# 39 -0.29892077729963273
# ...

# %%
measurements = np.random.normal(loc = 20, scale = 5, size = 100)
stats.probplot(measurements, dist = "norm", plot = pylab)
pylab.show()

# %% [markdown]
# ### Observation
# if (y(i),x(i)) for all i in 1 to 100
# lie on straight line than X and Y have same distribution.

# %% [markdown]
# ### Limitation:
#     1) If number of observation is less, it is harder to interpret QQ Plot

# %%
measurements = np.random.uniform(low = -1, high = 1, size = 100)
stats.probplot(measurements, dist= "norm", plot= pylab)
pylab.show()

# %% [markdown]
# #### Even if you have more number of observation however the more and more points abbreviates
